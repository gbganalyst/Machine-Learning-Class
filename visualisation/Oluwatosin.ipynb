# %%
import pandas as pd
import numpy as np

# %%
#load the dataset
df = pd.read_csv(r"C:\Users\HP\Downloads\code-snippet-for-part2\code-snippet-for-part2\datasets\west_africa.csv")

# %%
df.head()
# Out:
#         Country       Region  Total Cases  Total Deaths  Total Recovered  \
# 0         Benin  West Africa         3055            44             2907
# 1  Burkina Faso  West Africa         3156            68             2697
# 2    Cabo Verde  West Africa        11036           109            10541
# 3   Ivory Coast  West Africa        21485           132            21109
# 4        Gambia  West Africa         3770           123             3615
#
#    Active Cases  Serious_Critical  Population  Total Tests  Tests/1M pop
# 0           104               NaN    12257311     345560.0       28192.0
# 1           391               NaN    21145051          NaN           NaN
# 2           386              23.0      558576     105444.0      188773.0
# 3           244               NaN    26654550     225399.0        8456.0
# 4            32               2.0     2445287      26072.0       10662.0

# %%
df.shape
# Out:
# (17, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of           Country       Region  Total Cases  Total Deaths  Total Recovered  \
# 0           Benin  West Africa         3055            44             2907
# 1    Burkina Faso  West Africa         3156            68             2697
# 2      Cabo Verde  West Africa        11036           109            10541
# 3     Ivory Coast  West Africa        21485           132            21109
# 4          Gambia  West Africa         3770           123             3615
# 5           Ghana  West Africa        52198           325            51019
# 6          Guinea  West Africa        13233            76            12355
# 7   Guinea-Bissau  West Africa         2441            44             2327
# 8         Liberia  West Africa         1676            83             1358
# 9            Mali  West Africa         5135           164             3369
# 10     Mauritania  West Africa         9516           188             7849
# ...

# %%
#check missing values
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of     Country  Region  Total Cases  Total Deaths  Total Recovered  Active Cases  \
# 0     False   False        False         False            False         False
# 1     False   False        False         False            False         False
# 2     False   False        False         False            False         False
# 3     False   False        False         False            False         False
# 4     False   False        False         False            False         False
# 5     False   False        False         False            False         False
# 6     False   False        False         False            False         False
# 7     False   False        False         False            False         False
# 8     False   False        False         False            False         False
# 9     False   False        False         False            False         False
# 10    False   False        False         False            False         False
# ...

# %%
#drop duplicates
df=df.drop_duplicates()

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Serious_Critical', 'Population', 'Total Tests',
#        'Tests/1M pop'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.barplot(x="Country",y="Population",data=df)
plt.xticks(rotation=45)
plt.title("Population of West African Countries")
plt.show()

# %% [markdown]
# Nigeria has the highest population while Saint Helena has the lowest population.

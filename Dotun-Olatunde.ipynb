# %%
import seaborn as sns
import matplotlib.pyplot as plt

#Load the example titanic data
titan = sns.load_dataset("titanic")
#Create a count plot of any categorical variable 
sns.countplot(x = "class", data = titan)
plt.show()
